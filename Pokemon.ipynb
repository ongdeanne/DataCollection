# %%
import requests
URL = "https://bulbapedia.bulbagarden.net/wiki/List_of_Pok%C3%A9mon_by_National_Pok%C3%A9dex_number"

page = requests.get(URL)

from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

poke_content = soup.find(id = 'mw-content-text')
poke_tables = poke_content.find_all('table')

gen_json = []

for n in range(2, 9):
    gen_name = 'gen' + str(n) + '_list'
    gen_name = poke_tables[n]
    
    info_start = 3
    info_row = gen_name.contents[info_start]
    
    for i in range(info_start, len(gen_name.contents), 2):
        poke_info = gen_name.contents[i]
        kdex = poke_info.contents[1].text.strip()
        ndex = poke_info.contents[3].text.strip()
        for link in poke_info.contents[5].find_all('a'):
            url = 'https://bulbapedia.bulbagarden.net' + link.get('href')
        name = poke_info.contents[7].text.strip()
        type1 = poke_info.contents[9].text.strip()
        if len(poke_info.contents) > 10:
            type2 = poke_info.contents[11].text.strip()
            gen_json.append({
                "kdex": kdex,
                "ndex": ndex,
                "name": name,
                "type1": type1,
                "type2": type2,
                "URl": url
            })
        else:
            gen_json.append({
                "kdex": kdex,
                "ndex": ndex,
                "name": name,
                "type1": type1,
                "URL": url
            })
gen_json
# Out:
# [{'kdex': '#001',
#   'ndex': '#152',
#   'name': 'Chikorita',
#   'type1': 'Grass',
#   'URL': 'https://bulbapedia.bulbagarden.net/wiki/Chikorita_(Pok%C3%A9mon)'},
#  {'kdex': '#002',
#   'ndex': '#153',
#   'name': 'Bayleef',
#   'type1': 'Grass',
#   'URL': 'https://bulbapedia.bulbagarden.net/wiki/Bayleef_(Pok%C3%A9mon)'},
#  {'kdex': '#003',
#   'ndex': '#154',
#   'name': 'Meganium',
#   'type1': 'Grass',
#   'URL': 'https://bulbapedia.bulbagarden.net/wiki/Meganium_(Pok%C3%A9mon)'},
#  {'kdex': '#004',
#   'ndex': '#155',
#   'name': 'Cyndaquil',
#   'type1': 'Fire',
#   'URL': 'https://bulbapedia.bulbagarden.net/wiki/Cyndaquil_(Pok%C3%A9mon)'},
#  {'kdex': '#005',
#   'ndex': '#156',
#   'name': 'Quilava',
#   'type1': 'Fire',
#   'URL': 'https://bulbapedia.bulbagarden.net/wiki/Quilava_(Pok%C3%A9mon)'},
#  {'kdex': '#006',
#   'ndex': '#157',
#   'name': 'Typhlosion',
#   'type1': 'Fire',
#   'URL': 'https://bulbapedia.bulbagarden.net/wiki/Typhlosion_(Pok%C3%A9mon)'},
# ...
